# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import re
import yaml
import os

# %%
list_of_sections = [x for x in os.listdir('../src/data/2023') \
                    if len(x.split(' - ')) > 1]
section_numbers = [int(x.split(' ')[1]) for x in list_of_sections]
section_names = [x.split(' - ')[1].split('.')[0] for x in list_of_sections]

section_dict = dict(zip(section_numbers, section_names))

# %%
# %run -i "../src/code/comment.py"
# %run -i "../src/code/indicator.py"
# %run -i "../src/code/objects.py"
# %run -i "../src/code/periods.py"
# %run -i "../src/code/section.py"

# %%
year = 2023
section_num = 21
section_name = section_dict[section_num]
print(section_name)
# Out:
# Внешняя торговля

# %%
section = Section(
    source = f'../src/data/{year}/Раздел {section_num} - {section_name}.xlsx', 
    regions_dict = '../src/code/regions_etalon.yaml'
)

# %%
data, comm = section.process_sheet(f'21.1.1.')
display(data.sample(20))
display(comm)
# Out:
#                section                                     indicator_name  \
# 1979  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1591  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 385   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 938   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 249   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 2088  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1679  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 500   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1440  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 153   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1611  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1371  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 81    Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 894   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1272  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 985   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 728   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 84    Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1829  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1982  Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
#
#                                          indicator_unit indicator_code  \
# 1979  в фактически действовавших ценах, миллионов до...       21010100
# 1591  в фактически действовавших ценах, миллионов до...       21010100
# 385   в фактически действовавших ценах, миллионов до...       21010100
# 938   в фактически действовавших ценах, миллионов до...       21010100
# 249   в фактически действовавших ценах, миллионов до...       21010100
# 2088  в фактически действовавших ценах, миллионов до...       21010100
# 1679  в фактически действовавших ценах, миллионов до...       21010100
# 500   в фактически действовавших ценах, миллионов до...       21010100
# 1440  в фактически действовавших ценах, миллионов до...       21010100
# 153   в фактически действовавших ценах, миллионов до...       21010100
# 1611  в фактически действовавших ценах, миллионов до...       21010100
# 1371  в фактически действовавших ценах, миллионов до...       21010100
# 81    в фактически действовавших ценах, миллионов до...       21010100
# 894   в фактически действовавших ценах, миллионов до...       21010100
# 1272  в фактически действовавших ценах, миллионов до...       21010100
# 985   в фактически действовавших ценах, миллионов до...       21010100
# 728   в фактически действовавших ценах, миллионов до...       21010100
# 84    в фактически действовавших ценах, миллионов до...       21010100
# 1829  в фактически действовавших ценах, миллионов до...       21010100
# 1982  в фактически действовавших ценах, миллионов до...       21010100
#
#      subsection                          object_name       object_level  \
# 1979                                 Приморский край             регион
# 1591                             Челябинская область             регион
# 385                                 Тульская область             регион
# 938              Северо-Кавказский федеральный округ  федеральный округ
# 249                               Московская область             регион
# 2088                    Еврейская автономная область             регион
# 1679                              Республика Хакасия             регион
# 500                                  Республика Коми             регион
# 1440                     Уральский федеральный округ  федеральный округ
# 153                               Ивановская область             регион
# 1611                     Сибирский федеральный округ  федеральный округ
# 1371                               Самарская область             регион
# 81                                  Брянская область             регион
# 894                               Ростовская область             регион
# 1272                                   Пермский край             регион
# 985                             Республика Ингушетия             регион
# 728                          Южный федеральный округ  федеральный округ
# 84                                  Брянская область             регион
# 1829                                 Томская область             регион
# 1982                                Хабаровский край             регион
#
#      object_oktmo object_okato  year  indicator_value   comment
# 1979     05000000     05000000  2021         3395.600  21.1.1.1
# 1591     75000000     75000000  2007         5148.800  21.1.1.1
# 385      70000000     70000000  2011         3640.500  21.1.1.1
# 938      00000000     00000000  2014          797.100  21.1.1.1
# 249      46000000     46000000  2007         2282.600  21.1.1.1
# 2088     99000000     99000000  2020          197.600  21.1.1.1
# 1679     95000000     95000000  2007         1424.500  21.1.1.1
# 500      87000000     87000000  2016          697.900  21.1.1.1
# 1440     00000000     00000000  2010        54613.900  21.1.1.1
# 153      24000000     24000000  2021          160.700  21.1.1.1
# 1611     00000000     00000000  2005        22545.800  21.1.1.1
# 1371     36000000     36000000  2007         5232.400  21.1.1.1
# 81       15000000     15000000  2015          102.100  21.1.1.1
# 894      60000000     60000000  2014         3927.500  21.1.1.1
# 1272     57000000     57000000  2018         4828.900  21.1.1.1
# 985      26000000     26000000  2017            3.111  21.1.1.1
# 728      00000000     00000000  2002         3119.800  21.1.1.1
# 84       15000000     15000000  2018           94.100  21.1.1.1
# 1829     69000000     69000000  2003          518.300  21.1.1.1
# 1982     08000000     08000000  2002         1173.500  21.1.1.1
#   comment_number           section  \
# 0       21.1.1.1  Внешняя торговля
# 1       21.1.1.2  Внешняя торговля
#
#                                       indicator_name        comment_region  \
# 0  Внешняя торговля со странами дальнего зарубежь...                     –
# 1  Внешняя торговля со странами дальнего зарубежь...  Российская Федерация
#
#                                         comment_text
# 0  В связи с приостановкой публикации данных стат...
# 1  Данные за 2019, 2020, 2021 годы уточнены по со...

# %%
# Process and save the section

data, comments = section.process_section()
data.to_csv(f'../result/section_{section_num}.csv', encoding='utf-16', index=False)
comments.to_csv(f'../result/section_{section_num}_comments.csv', encoding='utf-16', index=False)
# Out:
# Обрабатываем лист 21.1.1.
# Обрабатываем лист 21.1.2.
# Обрабатываем лист 21.2.1.
# Обрабатываем лист 21.2.2.

# %%
data.sample(10)
# Out:
#                section                                     indicator_name  \
# 541   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 252   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 566   Внешняя торговля          Внешняя торговля со странами СНГ: Экспорт
# 948   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1862  Внешняя торговля           Внешняя торговля со странами СНГ: Импорт
# 846   Внешняя торговля          Внешняя торговля со странами СНГ: Экспорт
# 1673  Внешняя торговля           Внешняя торговля со странами СНГ: Импорт
# 1936  Внешняя торговля           Внешняя торговля со странами СНГ: Импорт
# 889   Внешняя торговля  Внешняя торговля со странами дальнего зарубежь...
# 1616  Внешняя торговля           Внешняя торговля со странами СНГ: Импорт
#
#                                          indicator_unit indicator_code  \
# 541   в фактически действовавших ценах, миллионов до...       21010200
# 252   в фактически действовавших ценах, миллионов до...       21010200
# 566   в фактически действовавших ценах, миллионов до...       21020100
# 948   в фактически действовавших ценах, миллионов до...       21010200
# 1862  в фактически действовавших ценах, миллионов до...       21020200
# 846   в фактически действовавших ценах, миллионов до...       21020100
# 1673  в фактически действовавших ценах, миллионов до...       21020200
# 1936  в фактически действовавших ценах, миллионов до...       21020200
# 889   в фактически действовавших ценах, миллионов до...       21010200
# 1616  в фактически действовавших ценах, миллионов до...       21020200
#
#      subsection                                   object_name  \
# 541                                 Ненецкий автономный округ
# 252                                        Московская область
# 566              Архангельская область без автономного округа
# 948                                       Республика Дагестан
# 1862                        Дальневосточный федеральный округ
# 846                                      Астраханская область
# 1673                                       Республика Хакасия
# 1936                                          Камчатский край
# 889                                        Ростовская область
# 1616                              Сибирский федеральный округ
#
#            object_level object_oktmo object_okato  year  indicator_value  \
# 541              регион     11800000     11100000  2013              0.7
# 252              регион     46000000     46000000  2010          19699.8
# 566              регион     11800000     11200000  2016            109.6
# 948              регион     82000000     82000000  2002             30.0
# 1862  федеральный округ     00000000     00000000  2014            306.2
# 846              регион     12000000     12000000  2010            191.5
# 1673             регион     95000000     95000000  2001            117.7
# 1936             регион     30000000     30000000  2000             10.5
# 889              регион     60000000     60000000  2009           1738.4
# 1616  федеральный округ     00000000     00000000  2010           1411.7
#
#        comment
# 541   21.1.2.1
# 252   21.1.2.1
# 566   21.2.1.1
# 948   21.1.2.1
# 1862  21.2.2.1
# 846   21.2.1.1
# 1673  21.2.2.1
# 1936  21.2.2.1
# 889   21.1.2.1
# 1616  21.2.2.1

# %%
comments
# Out:
#   comment_number           section  \
# 0       21.1.1.1  Внешняя торговля
# 1       21.1.1.2  Внешняя торговля
# 0       21.1.2.1  Внешняя торговля
# 1       21.1.2.2  Внешняя торговля
# 0       21.2.1.1  Внешняя торговля
# 1       21.2.1.2  Внешняя торговля
# 0       21.2.2.1  Внешняя торговля
# 1       21.2.2.2  Внешняя торговля
#
#                                       indicator_name        comment_region  \
# 0  Внешняя торговля со странами дальнего зарубежь...                     –
# 1  Внешняя торговля со странами дальнего зарубежь...  Российская Федерация
# 0  Внешняя торговля со странами дальнего зарубежь...                     –
# 1  Внешняя торговля со странами дальнего зарубежь...  Российская Федерация
# 0          Внешняя торговля со странами СНГ: Экспорт                     –
# 1          Внешняя торговля со странами СНГ: Экспорт  Российская Федерация
# 0           Внешняя торговля со странами СНГ: Импорт                     –
# 1           Внешняя торговля со странами СНГ: Импорт  Российская Федерация
#
#                                         comment_text
# 0  В связи с приостановкой публикации данных стат...
# 1  Данные за 2019, 2020, 2021 годы уточнены по со...
# 0  В связи с приостановкой публикации данных стат...
# 1  Данные за 2019, 2020, 2021 годы уточнены по со...
# 0  В связи с приостановкой публикации данных стат...
# 1  Данные за 2019, 2020, 2021 годы уточнены по со...
# 0  В связи с приостановкой публикации данных стат...
# 1  Данные за 2019, 2020, 2021 годы уточнены по со...
